# %%
# %matplotlib inline
import copy, numpy as np, scipy, pyo, matplotlib.pyplot as plt, pandas, librosa, essentia.standard, IPython.display

# %%
# Everything is mono for now
x = essentia.standard.MonoLoader(filename='wavs/125_bounce.wav')()
fs = 44100
print x.shape
IPython.display.Audio(x, rate=fs)
# Out:
# (338688,)
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(x, fs)

# %%
S, freqs, bins, im = plt.specgram(x, NFFT=1024, noverlap=512, Fs=44100)
plt.xlabel('Time (seconds)')
plt.ylabel('Frequency (Hz)')

# %%
onsets = librosa.onset.onset_detect(x, fs)
print onsets
# Out:
# [ 22  43  74  84 104 125 157 166 187 208 229 239 249 270 290 312 322 332
#  352 373 404 415 435 456 477 487 498 518 539 569 580 600 611 621 632]

# %%
S = librosa.stft(x)
logS = librosa.logamplitude(S)
librosa.display.specshow(logS, fs, alpha=0.75, x_axis='time')
plt.vlines(onsets, 0, logS.shape[0], color='r')

# %%
# Use this, is probably the best
find_onsets = essentia.standard.OnsetRate()
onsetTimes, onset_rate = find_onsets(x)
print onsetTimes
print onset_rate
# Out:
# [ 0.01160998  0.47600907  0.95201814  1.18421769  1.42802715  1.68344676
#   1.79954648  1.91564631  2.14784575  2.39165545  2.63546491  2.75156474
#   2.86766434  3.09986401  3.34367347  3.59909296  3.71519279  4.0634923
#   4.30730152  4.55111122  4.66721106  4.79492044  5.02712011  5.27092981
#   5.51473904  5.63083887  5.99074841  6.23455763  6.59446716  6.710567
#   6.94276667  7.08208609  7.18657589  7.33750582  7.44199562]
# 4.55729198456

# %%
onsets_marker = essentia.standard.AudioOnsetsMarker(onsets=onsetTimes, type='beep')
x_beeps = onsets_marker(x)
IPython.display.Audio(x_beeps, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
numRotations = 9
y = Rotate(x, fs, onsetTimes, numRotations)
IPython.display.Audio(y, rate=fs)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y = Syncopate(x, 4)
IPython.display.Audio(y, rate=fs)
# Out:
# > <ipython-input-93-0249bac335b0>(81)_LinearWindow()
# -> ramp = numpy.arange(0,1,1./rampLength)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-95-be5c3ab7d37e> in <module>()
# ----> 1 y = Syncopate(x, 4)
#       2 IPython.display.Audio(y, rate=fs)
#
# <ipython-input-93-0249bac335b0> in Syncopate(x, numSyncopations)
#      56     chunkStart = 0
#      57     for _unused in xrange(numSyncopations):
# ---> 58         newChunk = _LinearWindow(x[chunkStart:chunkStart+chunkLength])
#      59         y = np.append(y, newChunk) #there will be a random 0 at the beginnign from the np.empty ;(
#      60     return y
#
# <ipython-input-93-0249bac335b0> in _LinearWindow(x)
#      79     rampLength = (int) (len(x) * RAMP_FACTOR)
#      80     import pdb; pdb.set_trace()
# ---> 81     ramp = numpy.arange(0,1,1./rampLength)
#      82     y = numpy.copy(x)
#      83
#
# ...

# %%
def Reverse(x):
    """ 
    Reverses a segment of audio.
    
    Args:
        x: 1D array
     
    Returns:
        a copy of X, reversaflippydipped
    """
    arr = copy.copy(x)
    
    length = len(arr)
    for i in range(length/2):
        temp = arr[i]
        arr[i] = arr[length-i-1]
        arr[length-i-1] = temp
    return arr


def Rotate(x, fs, onsetTimes, numRotations):
    """
    Rotate audio by a number of onset times.
    
    Args:
        x: input signal
        fs: sampling freq
        onsetTimes: musical event times in seconds
        numRotations: desired num of rotations
    
    Returns:
        y: new rotated signal
    """
    cutTime = onsetTimes[len(onsetTimes) - numRotations]
    cutSample = int(cutTime * fs)
    # import pdb; pdb.set_trace()
    y = np.append(x[cutSample:], x[:cutSample])
    
    return y


def Syncopate(x, numSyncopations):
    """
    Syncopate a signal by just windowing.
    
    Args:
        x: the chunk of audio to syncopate
        fs: sampling freq
        numSyncopations: number of chunks to syncopate
    
    Returns:
        y: new syncopated signal
    """
    chunkLength = (int) (len(x) / numSyncopations)
    y = np.empty([1,1])
    chunkStart = 0
    for _unused in xrange(numSyncopations):
        newChunk = _LinearWindow(x[chunkStart:chunkStart+chunkLength])
        y = np.append(y, newChunk) #there will be a random 0 at the beginnign from the np.empty ;(
    return y


def _LinearWindow(x):
    """
    TODO: Make cooler windows -- exponential, etc. Linear is smelly
    Window the signal by fading in and out at ends.
    
    Questions:
        - what type of windowing? linear? exponential?
        - should the ramp time be constant or a function of the chunk length?
        
    Args:
        x: signal to be windowed
    
    Returns:
        y: windowed signal, yo.
    """
    RAMP_FACTOR = .1
    rampLength = (int) (len(x) * RAMP_FACTOR)
    ramp = numpy.arange(0,1,1./rampLength)
    y = numpy.copy(x)
    
    for i in xrange(rampLength):
        y[i] = y[i] * ramp[i]
        y[len(x) - i - 1] = y[len(x) - i - 1] * ramp[i]
        
    return y


def Reverb(x):
    pass
